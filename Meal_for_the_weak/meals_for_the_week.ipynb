# %%
import ast
import re
import pandas as pd
import numpy as np
from collections import defaultdict, Counter

# %%
df = pd.read_csv('povarenok_recipes_2021_06_16.csv')
df.head()
# Out:
#                                              url  \
# 0  https://www.povarenok.ru/recipes/show/164365/
# 1    https://www.povarenok.ru/recipes/show/1306/
# 2   https://www.povarenok.ru/recipes/show/10625/
# 3  https://www.povarenok.ru/recipes/show/167337/
# 4   https://www.povarenok.ru/recipes/show/91919/
#
#                                             name  \
# 0             Густой молочно-клубничный коктейль
# 1                                       Рулетики
# 2                            Салат "Баклажанчик"
# 3  Куриные котлеты с картофельным пюре в духовке
# 4                        Рецепт вишневой наливки
#
#                                          ingredients
# 0  {'Молоко': '250 мл', 'Клубника': '200 г', 'Сах...
# 1  {'Сыр твердый': None, 'Чеснок': None, 'Яйцо ку...
# 2  {'Баклажан': '3 шт', 'Лук репчатый': '2 шт', '...
# 3  {'Фарш куриный': '800 г', 'Пюре картофельное':...
# 4  {'Вишня': '1 кг', 'Водка': '1 л', 'Сахар': '30...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146582 entries, 0 to 146581
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   url          146582 non-null  object
#  1   name         146582 non-null  object
#  2   ingredients  146581 non-null  object
# dtypes: object(3)
# memory usage: 3.4+ MB

# %%
type(df["ingredients"][0])
# Out:
# str

# %%
# Функция для преобразования строки в dict
def to_dict(x):
    try:
        return ast.literal_eval(x) if isinstance(x, str) else {}
    except:
        return {}

# Превращаем колонку в словари
df['ingredients'] = df['ingredients'].apply(to_dict)

# %%
def clean_ingredient(ing):
  result = {}
  if isinstance(ing, dict):
    for k, v in ing.items():
      k = k.strip().lower()
      v = str(v).strip().lower()

      match = re.match(r'([\d.,]+)?\s*([а-яa-z]*)', v) # проблема начинается где-то тут, я проверил на другом экземпляре и выше код делает все правильно и как должно быть, а тут начинается проблема
      qty = match.group(1)
      unit = match.group(2)
      result[k] = {'quantity': qty, 'unit': unit}
  return result

df['ingredients'] = df['ingredients'].apply(clean_ingredient)
df.head()
# Out:
#                                              url  \
# 0  https://www.povarenok.ru/recipes/show/164365/
# 1    https://www.povarenok.ru/recipes/show/1306/
# 2   https://www.povarenok.ru/recipes/show/10625/
# 3  https://www.povarenok.ru/recipes/show/167337/
# 4   https://www.povarenok.ru/recipes/show/91919/
#
#                                             name  \
# 0             Густой молочно-клубничный коктейль
# 1                                       Рулетики
# 2                            Салат "Баклажанчик"
# 3  Куриные котлеты с картофельным пюре в духовке
# 4                        Рецепт вишневой наливки
#
#                                          ingredients
# 0  {'молоко': {'quantity': '250', 'unit': 'мл'}, ...
# 1  {'сыр твердый': {'quantity': None, 'unit': 'no...
# 2  {'баклажан': {'quantity': '3', 'unit': 'шт'}, ...
# 3  {'фарш куриный': {'quantity': '800', 'unit': '...
# 4  {'вишня': {'quantity': '1', 'unit': 'кг'}, 'во...

# %%
df['ingredients'].iloc[0]
# Out:
# {'молоко': {'quantity': '250', 'unit': 'мл'},
#  'клубника': {'quantity': '200', 'unit': 'г'},
#  'сахар': {'quantity': '15', 'unit': 'г'}}

# %%
ingredient_values = defaultdict(list)
ingredient_units = defaultdict(list)

for ing_dict in df['ingredients']:
  for name, info in ing_dict.items():
    qty = info.get('quantity')
    unit = info.get('unit')

    if qty not in [None, 'none', np.nan, 'None']:
      try:
        qty_val = float(str(qty).replace(',','.'))
        ingredient_values[name].append(qty_val)
      except:
        pass
    if unit not in [None, 'none', np.nan, 'None']:
      ingredient_units[name].append(unit)

ingredient_means = {k: np.mean(v) for k, v in ingredient_values.items() if v}
ingredient_mode_unit = {k: Counter(v).most_common(1)[0][0] for k, v in ingredient_units.items() if v}

# %%
def fill_nan_quantities_and_units(ing_dict):
  new_dict = {}
  for name, info in ing_dict.items():
    qty = info.get('quantity')
    unit = info.get('unit')

    if qty not in [None, 'none', np.nan, 'None']:
      new_qty = round(ingredient_means.get(name, 1.0), 2)
    else:
      try:
        new_qty = float(str(qty).replace(',','.'))
      except:
        new_qty = 1.0

    if unit not in [None, 'none', np.nan, 'None']:
      new_unit = unit
    else:
      new_unit = ingredient_mode_unit.get(name, 'шт')

    new_dict[name] = {'quantity': new_qty, 'unit': new_unit}
  return new_dict

df['ingredients'] = df['ingredients'].apply(fill_nan_quantities_and_units)

# %%
# Пример: случайно выбрать 14 блюд на неделю (2 в день)
week_meals = df.sample(14, random_state=42)

# %%
def aggregate_ingredients(selected_meals):
    shopping_list = defaultdict(lambda: {'quantity': 0.0, 'unit': None})

    for ing_dict in selected_meals['ingredients']:
        for name, info in ing_dict.items():
            qty = info.get('quantity')
            unit = info.get('unit')

            # Преобразуем количество в число (если возможно)
            try:
                qty_val = float(str(qty).replace(',', '.')) if qty else 1.0
            except:
                qty_val = 1.0

            # Если единицы измерения совпадают — суммируем
            if shopping_list[name]['unit'] in [unit, None]:
                # Если quantity вдруг оказался строкой, сбрасываем в 0
                if not isinstance(shopping_list[name]['quantity'], (int, float)):
                    shopping_list[name]['quantity'] = 0.0

                shopping_list[name]['quantity'] += qty_val
                shopping_list[name]['unit'] = unit
            else:
                # Разные единицы — добавляем как текстовое примечание
                existing_qty = str(shopping_list[name]['quantity'])
                shopping_list[name]['quantity'] = f"{existing_qty} + {qty} {unit}"

    return shopping_list

# %%
def show_recipes(df, dish_names):
    """
    Выводит названия блюд и их ингредиенты для списка блюд из DataFrame.
    """
    for dish in dish_names:
        row = df.loc[df['name'] == dish]

        if row.empty:
            print(f"Блюдо '{dish}' не найдено.\n")
            continue

        ingredients = row.iloc[0]['ingredients']

        # если ингредиенты записаны как строка — конвертируем
        if isinstance(ingredients, str):
            try:
                ingredients = ast.literal_eval(ingredients)
            except Exception as e:
                print(f"⚠️ Не удалось распарсить ингредиенты для '{dish}': {e}")
                continue

        print(f"{dish}\nИнгредиенты:")
        for name, info in ingredients.items():
            quantity = info.get('quantity', '')
            unit = info.get('unit', '')
            print(f" - {name}: {quantity} {unit}")
        print("\n" + "-" * 40 + "\n")

# %%
print(f"Meals for a week\n")

shopping_list = aggregate_ingredients(week_meals)
dish_name_list = [k for k in week_meals['name']]
show_recipes(week_meals, dish_name_list)
# Out:
# Meals for a week
#
# Итaльянский розмариновый кекс
# Ингредиенты:
#  - яйцо куриное: 2.86 шт
#  - сахар: 61.59
#  - масло оливковое: 14.85
#  - розмарин: 1.77
#  - мука пшеничная: 141.88
#  - порошок пекарский: 2.2 ст
#  - соль: 1.0 по
#
# ----------------------------------------
#
# Японский фруктовый мусс
# Ингредиенты:
#  - яблоко: 40.18 шт
#  - груша: 39.42 шт
#  - киви: 13.63 шт
#  - апельсин: 8.74 шт
#  - белок яичный: 11.14 шт
#
# ----------------------------------------
#
# Хлебные котлетки к жареной рыбе
# Ингредиенты:
#  - хлеб: 43.95
#  - молоко: 139.73
#  - фета: 124.91
#  - сыр твердый: 116.37
#  - яйцо куриное: 2.86 шт
#  - сухари панировочные: 1.0 ст
#  - лук зеленый: 1.0 пуч
#  - петрушка: 1.0 пуч
#  - специи: 1.0 по
#  - йогурт: 144.31 бан
#  - лимон: 2.27
#  - масло оливковое: 1.0 ст
#  - чеснок: 4.74
#  - рыба: 203.56
#  - горчица: 3.43 ст
#  - мука пшеничная: 141.88 стак
#
# ----------------------------------------
#
# Хумус из зеленой гречки
# Ингредиенты:
#  - крупа гречневая: 56.92 стак
#  - петрушка: 6.05
#  - тархун: 16.88
#  - оливки зеленые: 32.58 шт
#  - чеснок: 4.74 зуб
#  - мука кунжутная: 7.3 ст
#  - масло оливковое: 14.85 ст
#  - соевый соус: 11.54 ст
#  - сок лимонный: 4.73 ст
#  - соль: 1.0 по
#
# ----------------------------------------
#
# Салат "Дамский"
# Ингредиенты:
#  - свекла: 54.15 шт
#  - апельсин: 8.74 шт
#  - огурец маринованный: 23.85 шт
#  - лук красный: 8.79 шт
#  - орехи грецкие: 57.71 горст
#  - майонез: 1.0 по
#  - соль: 1.0 по
#
# ----------------------------------------
#
# Английская каша
# Ингредиенты:
#  - молоко: 139.73 стак
#  - вода: 129.49 стак
#  - овес: 35.82 стак
#  - хлопья овсяные: 50.37 стак
#  - сахар: 61.59 ст
#  - соль: 4.11 ч
#
# ----------------------------------------
#
# Хлебный сундучок с яичницей и овощами
# Ингредиенты:
#  - перец болгарский: 1.0 шт
#  - шампиньоны: 1.0 г
#  - сыр твердый: 1.0 г
#  - хлеб: 1.0 ломт
#  - яйцо куриное: 1.0 шт
#
# ----------------------------------------
#
# Тортинки
# Ингредиенты:
#  - масло сливочное: 92.05 г
#  - сахар: 61.59 стак
#  - яйцо куриное: 2.86 шт
#  - мука пшеничная: 141.88 стак
#  - соль: 4.11 ч
#  - сода гашеная уксусом: 0.94 ч
#  - хлопья овсяные: 50.37 ст
#  - шоколад темный: 108.29 г
#
# ----------------------------------------
#
# Сметанные блинчики с ягодами
# Ингредиенты:
#  - мука пшеничная: 141.88 ст
#  - сода: 1.1
#  - яйцо куриное: 2.86 шт
#  - сметана: 107.65
#  - сахар: 61.59 ст
#  - соль: 4.11
#  - ягода: 155.36
#
# ----------------------------------------
#
# Печеночный торт
# Ингредиенты:
#  - печень куриная: 361.31 г
#  - лук репчатый: 13.66 шт
#  - молоко: 139.73 мл
#  - мука пшеничная: 141.88 г
#  - яйцо куриное: 2.86 шт
#  - масло растительное: 26.15 ст
#  - соль: 1.0 по
#  - перец черный: 1.0 по
#  - морковь: 29.85 г
#  - огурец: 21.9 шт
#  - петрушка: 1.0 пуч
#  - укроп: 1.0 пуч
#  - майонез: 58.36 г
#  - чеснок: 4.74 зуб
#
# ----------------------------------------
#
# Диетическая запеканка "Овсянка, сэр"
# Ингредиенты:
#  - яйцо куриное: 2.86 шт
#  - сыворотка: 194.76 мл
#  - хлопья овсяные: 50.37 г
#  - цуккини: 60.74 г
#  - ветчина: 157.85 г
#  - соль: 1.0 по
#  - приправа: 1.0 по
#  - разрыхлитель теста: 2.38
#
# ----------------------------------------
#
# Мини-киш с луком-пореем и брокколи
# Ингредиенты:
#  - мука пшеничная: 141.88 г
#  - соль: 1.0 по
#  - масло сливочное: 92.05 г
#  - вода: 129.49 ст
#  - брокколи: 197.81 г
#  - лук-порей: 32.27 г
#  - яйцо куриное: 2.86 шт
#  - сливки: 174.84 мл
#  - сметана: 107.65 г
#  - сыр твердый: 116.37 г
#  - тимьян: 2.03 ч
#  - специи: 1.0 по
#
# ----------------------------------------
#
# Овощной салат с курицей
# Ингредиенты:
#  - фасоль стручковая: 190.75 пуч
#  - огурец: 21.9 шт
#  - грудка куриная: 128.42 шт
#  - морковь: 29.85 шт
#  - соевый соус: 11.54 ст
#  - масло растительное: 26.15 ст
#  - горчица: 3.43 ч
#  - кунжут: 10.4 ст
#  - специи: 2.06 ч
#  - лук репчатый: 13.66 шт
#
# ----------------------------------------
#
# Двухцветный творожный торт
# Ингредиенты:
#  - печенье: 172.93 г
#  - корица: 1.34 ч
#  - масло сливочное: 92.05 г
#  - желатин: 11.91 ст
#  - вода: 129.49
#  - творог: 273.13 г
#  - молоко: 139.73 стак
#  - сахарная пудра: 65.98 стак
#  - сливки: 174.84 стак
#  - шоколад молочный: 95.79 г
#  - шоколад темный: 108.29 г
#
# ----------------------------------------

# %%
print(f"\n\nIngredients\n")

n = 1
for k, v in shopping_list.items():
    print(f"{n}. {k}: {v['quantity']} {v['unit'] or ''}")
    n += 1
# Out:
# Ingredients
#
# 1. яйцо куриное: 21.02 шт
# 2. сахар: 61.59 + 61.59 ст + 61.59 стак + 61.59 ст
# 3. масло оливковое: 14.85 + 1.0 ст + 14.85 ст
# 4. розмарин: 1.77
# 5. мука пшеничная: 141.88 + 141.88 стак + 141.88 стак + 141.88 ст + 141.88 г + 141.88 г
# 6. порошок пекарский: 2.2 ст
# 7. соль: 3.0 по
# 8. яблоко: 40.18 шт
# 9. груша: 39.42 шт
# 10. киви: 13.63 шт
# 11. апельсин: 17.48 шт
# 12. белок яичный: 11.14 шт
# 13. хлеб: 43.95 + 1.0 ломт
# 14. молоко: 139.73 + 139.73 стак + 139.73 мл + 139.73 стак
# 15. фета: 124.91
# 16. сыр твердый: 116.37 + 1.0 г + 116.37 г
# 17. сухари панировочные: 1.0 ст
# 18. лук зеленый: 1.0 пуч
# 19. петрушка: 1.0 пуч
# 20. специи: 2.0 + 2.06 ч по
# 21. йогурт: 144.31 бан
# 22. лимон: 2.27
# 23. чеснок: 4.74 + 4.74 зуб + 4.74 зуб
# 24. рыба: 203.56
# 25. горчица: 3.43 + 3.43 ч ст
# 26. крупа гречневая: 56.92 стак
# 27. тархун: 16.88
# 28. оливки зеленые: 32.58 шт
# 29. мука кунжутная: 7.3 ст
# 30. соевый соус: 23.08 ст
# 31. сок лимонный: 4.73 ст
# 32. свекла: 54.15 шт
# 33. огурец маринованный: 23.85 шт
# 34. лук красный: 8.79 шт
# 35. орехи грецкие: 57.71 горст
# 36. майонез: 1.0 + 58.36 г по
# 37. вода: 129.49 + 129.49 ст + 129.49  стак
# 38. овес: 35.82 стак
# 39. хлопья овсяные: 50.37 + 50.37 ст + 50.37 г стак
# 40. перец болгарский: 1.0 шт
# 41. шампиньоны: 1.0 г
# 42. масло сливочное: 276.15 г
# 43. сода гашеная уксусом: 0.94 ч
# 44. шоколад темный: 216.58 г
# 45. сода: 1.1
# 46. сметана: 107.65 + 107.65 г
# 47. ягода: 155.36
# 48. печень куриная: 361.31 г
# 49. лук репчатый: 27.32 шт
# 50. масло растительное: 52.3 ст
# 51. перец черный: 1.0 по
# 52. морковь: 29.85 + 29.85 шт г
# 53. огурец: 43.8 шт
# 54. укроп: 1.0 пуч
# 55. сыворотка: 194.76 мл
# 56. цуккини: 60.74 г
# 57. ветчина: 157.85 г
# 58. приправа: 1.0 по
# 59. разрыхлитель теста: 2.38
# 60. брокколи: 197.81 г
# 61. лук-порей: 32.27 г
# 62. сливки: 174.84 + 174.84 стак мл
# 63. тимьян: 2.03 ч
# 64. фасоль стручковая: 190.75 пуч
# 65. грудка куриная: 128.42 шт
# 66. кунжут: 10.4 ст
# 67. печенье: 172.93 г
# 68. корица: 1.34 ч
# 69. желатин: 11.91 ст
# 70. творог: 273.13 г
# 71. сахарная пудра: 65.98 стак
# 72. шоколад молочный: 95.79 г

# %%
def test(df):
    week_meals = df.sample(14)
    shopping_list = aggregate_ingredients(week_meals)
    print(f"Meals for a week\n")

    shopping_list = aggregate_ingredients(week_meals)
    dish_name_list = [k for k in week_meals['name']]
    show_recipes(week_meals, dish_name_list)
    
    print(f"\n\nIngredients\n")

    n = 1
    for k, v in shopping_list.items():
        print(f"{n}. {k}: {v['quantity']} {v['unit'] or ''}")
        n += 1

test(df)
# Out:
# Meals for a week
#
# Куриное филе с сыром дорблю и беконом
# Ингредиенты:
#  - бедро куриное: 104.14 шт
#  - сыр голубой: 84.3 г
#  - соевый соус: 11.54 ст
#  - соус: 1.0 ст
#  - чеснок: 4.74 зуб
#  - овощи: 1.0 г
#  - зелень: 1.0 пуч
#  - бекон: 1.0 г
#  - соль: 1.0 по
#
# ----------------------------------------
#
# Соленые огурцы с красной смородиной на зиму
# Ингредиенты:
#  - огурец: 21.9 г
#  - смородина красная: 126.51 г
#  - перец черный: 2.57 шт
#  - чеснок: 4.74 зуб
#  - укроп: 5.66 шт
#  - соль: 4.11 ст
#  - сахар: 61.59 ч
#
# ----------------------------------------
#
# Щи рахмановские
# Ингредиенты:
#  - рыба: 1.0 г
#  - щавель: 1.0 пуч
#  - лук репчатый: 13.66 шт
#  - морковь: 29.85 шт
#  - картофель: 82.89 шт
#  - вода: 129.49 л
#  - сметана: 1.0 г
#  - соль: 1.0 по
#  - перец душистый: 1.0 шт
#  - лист лавровый: 1.0 шт
#
# ----------------------------------------
#
# Главная  >
#   Рецепты
#         >
#
# версия для печати
# Ингредиенты:
#  - мука пшеничная: 141.88 г
#  - масло сливочное: 92.05 г
#  - сахар: 61.59 г
#  - яйцо куриное: 2.86 шт
#  - соль: 4.11 щепот
#  - какао-порошок: 10.02 ст
#  - разрыхлитель теста: 2.38 ч
#  - шоколад темный: 108.29 г
#  - масло растительное: 26.15 ч
#  - ванильный сахар: 2.86 ст
#  - мастика: 1.0 г
#  - мята: 6.78 веточ
#  - молоко: 139.73 мл
#
# ----------------------------------------
#
# Яблочная пицца
# Ингредиенты:
#  - яблоко: 40.18 шт
#  - вода: 129.49 стак
#  - дрожжи: 9.33 ч
#  - соль: 4.11 ч
#  - сахар: 61.59 ч
#  - корица: 1.34 ч
#  - мука пшеничная: 141.88 стак
#  - масло растительное: 26.15
#
# ----------------------------------------
#
# Перцы "Светофоры"
# Ингредиенты:
#  - апельсин: 8.74 шт
#  - лук репчатый: 13.66
#  - соевый соус: 11.54 ст
#  - мидии: 189.05 г
#  - рис: 79.04 стак
#  - масло растительное: 26.15 г
#  - вода: 129.49 мл
#  - перец болгарский: 1.0 шт
#
# ----------------------------------------
#
# Торт "Ягодное суфле и желе в шоколаде"
# Ингредиенты:
#  - шоколад темный: 108.29 г
#  - яйцо куриное: 2.86 шт
#  - сахар: 61.59 г
#  - масло сливочное: 92.05 г
#  - мука пшеничная: 141.88 ст
#  - сок свежевыжатый: 113.57 мл
#  - желатин: 11.91 г
#  - вишня: 181.23 г
#  - пюре фруктовое: 153.97 г
#  - сливки: 174.84 ст
#
# ----------------------------------------
#
# Салат из куриного филе с огурцами
# Ингредиенты:
#  - филе куриное: 247.04 шт
#  - огурец: 21.9 шт
#  - сыр твердый: 116.37 г
#  - соус: 31.15 ч
#  - сок лимонный: 4.73 ч
#  - масло растительное: 26.15 ст
#  - листья салата: 1.0 пуч
#  - соль: 1.0 по
#
# ----------------------------------------
#
# Грибной суп
# Ингредиенты:
#  - бульон: 176.39 л
#  - картофель: 82.89
#  - шампиньоны: 191.58 г
#  - лук репчатый: 1.0 шт
#  - крупа гречневая: 56.92
#  - соль: 1.0 по
#  - перец черный: 1.0 по
#  - сметана: 1.0 г
#
# ----------------------------------------
#
# Блинные мини-пиццы с припеком
# Ингредиенты:
#  - кефир: 128.71 мл
#  - яйцо куриное: 2.86 шт
#  - сахар: 61.59 ст
#  - мука пшеничная: 141.88 г
#  - сода: 1.1 ч
#  - масло растительное: 1.0 ст
#  - колбаса: 164.49 г
#  - сосиска: 38.88 г
#  - помидор: 39.88 шт
#  - сыр твердый: 116.37 г
#
# ----------------------------------------
#
# Ванильное пирожное в шоколадном муссе
# Ингредиенты:
#  - яйцо куриное: 2.86 шт
#  - сахар: 61.59 ст
#  - мука пшеничная: 141.88 ст
#  - крахмал кукурузный: 15.82 ст
#  - ванильная эссенция: 1.38
#  - крем: 96.64 пакет
#  - молоко: 139.73 мл
#  - масло сливочное: 92.05 г
#  - желатин: 11.91 ст
#  - ванильный сахар: 2.86 ст
#  - белок яичный: 11.14 шт
#  - сироп сахарный: 1.0 по
#  - взбитые сливки: 1.0 по
#  - стружка кокосовая: 1.0 по
#  - посыпка кондитерская: 1.0 по
#
# ----------------------------------------
#
# Шашлык из индейки
# Ингредиенты:
#  - масло кунжутное: 3.42 стак
#  - соевый соус: 11.54 стак
#  - имбирь: 7.8 ст
#  - перец черный: 2.57 ч
#  - филе куриное: 247.04 кг
#  - кабачок: 64.46 шт
#  - перец болгарский: 20.6 шт
#  - лук репчатый: 13.66 шт
#  - картофель: 82.89 шт
#  - масло растительное: 26.15 ст
#  - лимон: 2.27 ч
#
# ----------------------------------------
#
# Салат "Фантазия"
# Ингредиенты:
#  - помидор: 39.88 шт
#  - огурец: 21.9 шт
#  - яйцо куриное: 2.86 шт
#  - листья салата: 30.36 пуч
#  - фета: 124.91 г
#  - сметана: 1.0 г
#  - специи: 1.0 по
#  - зелень: 1.0 пуч
#  - колбаса: 1.0 г
#
# ----------------------------------------
#
# Огуречно-йогуртовый суп
# Ингредиенты:
#  - огурец: 21.9 шт
#  - лук репчатый: 13.66 шт
#  - петрушка: 6.05 пуч
#  - укроп: 5.66 пуч
#  - базилик: 4.2 шт
#  - бульон: 176.39 мл
#  - йогурт: 144.31 г
#  - соль: 1.0 по
#  - перец черный: 1.0 по
#  - паприка сладкая: 1.0 по
#
# ----------------------------------------
#
#
#
# Ingredients
#
# 1. бедро куриное: 104.14 шт
# 2. сыр голубой: 84.3 г
# 3. соевый соус: 23.08 + 11.54 стак ст
# 4. соус: 1.0 + 31.15 ч ст
# 5. чеснок: 9.48 зуб
# 6. овощи: 1.0 г
# 7. зелень: 2.0 пуч
# 8. бекон: 1.0 г
# 9. соль: 3.0 по
# 10. огурец: 21.9 + 21.9 шт + 21.9 шт + 21.9 шт г
# 11. смородина красная: 126.51 г
# 12. перец черный: 2.57 + 1.0 по + 2.57 ч + 1.0 по шт
# 13. укроп: 5.66 + 5.66 пуч шт
# 14. сахар: 61.59 + 61.59 г + 61.59 ст + 61.59 ст ч
# 15. рыба: 1.0 г
# 16. щавель: 1.0 пуч
# 17. лук репчатый: 28.32 шт
# 18. морковь: 29.85 шт
# 19. картофель: 82.89 шт
# 20. вода: 129.49 + 129.49 стак + 129.49 мл л
# 21. сметана: 3.0 г
# 22. перец душистый: 1.0 шт
# 23. лист лавровый: 1.0 шт
# 24. мука пшеничная: 141.88 + 141.88 ст г
# 25. масло сливочное: 276.15 г
# 26. яйцо куриное: 14.299999999999999 шт
# 27. какао-порошок: 10.02 ст
# 28. разрыхлитель теста: 2.38 ч
# 29. шоколад темный: 216.58 г
# 30. масло растительное: 26.15 + 26.15  + 26.15 г + 26.15 ст + 1.0 ст + 26.15 ст ч
# 31. ванильный сахар: 5.72 ст
# 32. мастика: 1.0 г
# 33. мята: 6.78 веточ
# 34. молоко: 279.46 мл
# 35. яблоко: 40.18 шт
# 36. дрожжи: 9.33 ч
# 37. корица: 1.34 ч
# 38. апельсин: 8.74 шт
# 39. мидии: 189.05 г
# 40. рис: 79.04 стак
# 41. перец болгарский: 21.6 шт
# 42. сок свежевыжатый: 113.57 мл
# 43. желатин: 11.91 + 11.91 ст г
# 44. вишня: 181.23 г
# 45. пюре фруктовое: 153.97 г
# 46. сливки: 174.84 ст
# 47. филе куриное: 247.04 + 247.04 кг шт
# 48. сыр твердый: 232.74 г
# 49. сок лимонный: 4.73 ч
# 50. листья салата: 31.36 пуч
# 51. бульон: 176.39 + 176.39 мл л
# 52. шампиньоны: 191.58 г
# 53. крупа гречневая: 56.92
# 54. кефир: 128.71 мл
# 55. сода: 1.1 ч
# 56. колбаса: 165.49 г
# 57. сосиска: 38.88 г
# 58. помидор: 79.76 шт
# 59. крахмал кукурузный: 15.82 ст
# 60. ванильная эссенция: 1.38
# 61. крем: 96.64 пакет
# 62. белок яичный: 11.14 шт
# 63. сироп сахарный: 1.0 по
# 64. взбитые сливки: 1.0 по
# 65. стружка кокосовая: 1.0 по
# 66. посыпка кондитерская: 1.0 по
# 67. масло кунжутное: 3.42 стак
# 68. имбирь: 7.8 ст
# 69. кабачок: 64.46 шт
# 70. лимон: 2.27 ч
# 71. фета: 124.91 г
# 72. специи: 1.0 по
# 73. петрушка: 6.05 пуч
# 74. базилик: 4.2 шт
# 75. йогурт: 144.31 г
# 76. паприка сладкая: 1.0 по
